# %%
from selenium import webdriver
from selenium.webdriver.remote.webdriver import WebDriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('C:\\the\\directory\\of\\chromedriver.exe')
driver.get('https://www.company.com/jobs')

wait = WebDriverWait(driver, 10)

#Saves and grabs Session Information
executor_url = driver.command_executor._url
session_id = driver.session_id

print (session_id)
print (executor_url)

# %%
#RUN THIS CELL WITH LINK TO FIRST PAGE - This Cell will allow 
#you to stay within the session above log in load resume pages etc
#You can interact with this session and watch selenium run live

def attach_to_session(executor_url, session_id):
    original_execute = WebDriver.execute
    def new_command_execute(self, command, params=None):
        if command == "newSession":
            # Mock the response
            return {'success': 0, 'value': None, 'sessionId': session_id}
        else:
            return original_execute(self, command, params)
    # Patch the function before creating the driver object
    WebDriver.execute = new_command_execute
    driver = webdriver.Remote(command_executor=executor_url, desired_capabilities={})
    driver.session_id = session_id
    # Replace the patched function with original function
    WebDriver.execute = original_execute
    return driver

bro = attach_to_session( executor_url , session_id)

#Insert Link to first page of Application
#This will load the page in your current session
bro.get('https://www.company.com/jobs/listing/3915779/apply')

# %%
#INSPECT ELEMENT, COPY XPATH BY SEARCHING FOR ELEMENT

first_name = '//*[@id="jf01-form-container__form"]/div[1]/div/div[1]/div/div/div/input'
last_name = '//*[@id="jf01-form-container__form"]/div[1]/div/div[2]/div/div/div/input'
email = '//*[@id="jf01-form-container__form"]/div[1]/div/div[3]/div/div/div/input'
phone = '//*[@id="jf01-form-container__form"]/div[1]/div/div[4]/div/div/div/input'
attach = '//*[@id="jf01-form-container__form"]/div[1]/div/div[5]/div/div/div/div[1]/a[1]'
type_file = '//*[@id="jf01-form-container__form"]/div[1]/div/div[5]/div/div/div/div[2]/input'
lip = '//*[@id="jf01-form-container__form"]/div[1]/div/div[7]/div/div/div/input'
website = '//*[@id="jf01-form-container__form"]/div[1]/div/div[8]/div/div/div/input'
hear = '//*[@id="jf01-form-container__form"]/div[1]/div/div[9]/div/div/div/select'
jobop = '//*[@id="jf01-form-container__form"]/div[1]/div/div[10]/div/div/div/select'
reloc = '//*[@id="jf01-form-container__form"]/div[1]/div/div[12]/div/div/div/select'
workus = '//*[@id="jf01-form-container__form"]/div[1]/div/div[11]/div/div/div/select'
current = '//*[@id="jf01-form-container__form"]/div[1]/div/div[13]/div/div/div/select'
previous = '//*[@id="jf01-form-container__form"]/div[1]/div/div[14]/div/div/div/select'
pronouns = '//*[@id="jf01-form-container__form"]/div[1]/div/div[15]/div/div/div/select'
legal_name = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/input'

#These are regular Insert Text inputs
driver.find_element_by_xpath(first_name).send_keys('Johnny')
driver.find_element_by_xpath(last_name).send_keys('Bravo')
driver.find_element_by_xpath(email).send_keys('J.Bravo@gmail.com')
driver.find_element_by_xpath(phone).send_keys('5551235555')

#Load Resume - the Attach or Browse button needs to be clicked it will reveal
#a hidden "input=file" element you need to send the path to this xpath
driver.find_element_by_xpath(attach).click()
file_upload = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH,type_file)))
file_upload.send_keys('C:\\the\\directory\\of\\Resume_JB_2021.pdf')

driver.find_element_by_xpath(lip).send_keys('https://www.linkedin.com/in/JB-CN/')
driver.find_element_by_xpath(website).send_keys('https://github.com/JB21/')

#the selects are of drop boxes these were fairly simple sometimes these are the tougest
#they can be hidden and must be clicked if not interactable to make them interactable the select text

select = Select(driver.find_element_by_xpath(hear))
select.select_by_visible_text('LinkedIn')

select = Select(driver.find_element_by_xpath(jobop))
select.select_by_visible_text('Yes')

select = Select(driver.find_element_by_xpath(reloc))
select.select_by_visible_text('No')

select = Select(driver.find_element_by_xpath(workus))
select.select_by_visible_text('1. I am authorized to work US')

select = Select(driver.find_element_by_xpath(current))
select.select_by_visible_text('US - Georgia')

select = Select(driver.find_element_by_xpath(previous))
select.select_by_visible_text('No, I have not previously worked for this Company')

select = Select(driver.find_element_by_xpath(pronouns))
select.select_by_visible_text('He / Him / His')

driver.find_element_by_xpath(legal_name).send_keys('John')

driver.find_element_by_xpath('//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/a').click()
driver.find_element_by_xpath('//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/a').click()

School = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[1]/div/div/div/input[1]'
School_A = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[1]/div/div/div/div/input'
Degree = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[2]/div/div/div/input[1]'
Degree_A = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[2]/div/div/div/div/input'
Discipline = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[3]/div/div/div/input[1]'
Discipline_A = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[3]/div/div/div/div/input'
Start = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[4]/div/div/div/select'
S_Year = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[4]/div/div/div/input'
End = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[5]/div/div/div/select'
E_Year = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[1]/div/div[5]/div/div/div/input'

#These next blocks were auto complete textboxes, as you typed it gives you options to select figure out
#which option you need, type, and arrow down return the exact selection. The auto select was not revealed
#until it was clicked. Some issues like these need to be analyzed to figure out the steps to automate.

driver.find_element_by_xpath(School).click()
elem = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, School_A)))
elem.send_keys("University of South Carolina")
elem.send_keys(Keys.ARROW_DOWN)
auto_option = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, School_A)))
auto_option.send_keys(Keys.RETURN)

driver.find_element_by_xpath(Degree).click()
elem = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Degree_A)))
elem.send_keys("Bachelor")
elem.send_keys(Keys.ARROW_DOWN)
auto_option = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Degree_A)))
auto_option.send_keys(Keys.RETURN)

driver.find_element_by_xpath(Discipline).click()
elem = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Discipline_A)))
elem.send_keys("Computer Science")
elem.send_keys(Keys.ARROW_DOWN)
auto_option = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Discipline_A)))
auto_option.send_keys(Keys.RETURN)

select = Select(driver.find_element_by_xpath(Start))
select.select_by_visible_text('8')

driver.find_element_by_xpath(S_Year).send_keys('2010')

select = Select(driver.find_element_by_xpath(End))
select.select_by_visible_text('12')

driver.find_element_by_xpath(E_Year).send_keys('2014')



School_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[1]/div/div/div/input[1]'
School_A_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[1]/div/div/div/div/input'
Degree_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[2]/div/div/div/input[1]'
Degree_A_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[2]/div/div/div/div/input'
Discipline_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[3]/div/div/div/input[1]'
Discipline_A_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[3]/div/div/div/div/input'
Start_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[4]/div/div/div/select'
S_Year_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[4]/div/div/div/input'
End_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[5]/div/div/div/select'
E_Year_1 = '//*[@id="jf01-form-container__form"]/div[1]/div/div[16]/div/div/div/ul/li[2]/div/div[5]/div/div/div/input'

Company = '//*[@id="jf01-form-container__form"]/div[1]/div/div[17]/div/div/div/ul/li/div/div[1]/div/div/div/input[1]'
Title = '//*[@id="jf01-form-container__form"]/div[1]/div/div[17]/div/div/div/ul/li/div/div[2]/div/div/div/input'
Start_M = '//*[@id="jf01-form-container__form"]/div[1]/div/div[17]/div/div/div/ul/li/div/div[3]/div/div/div/select'
Start_Y = '//*[@id="jf01-form-container__form"]/div[1]/div/div[17]/div/div/div/ul/li/div/div[3]/div/div/div/input'

Job_AA = '//*[@id="jf01-form-container__form"]/div[1]/div/div[17]/div/div/div/a'
Current_CHK = '//*[@id="jf01-form-container__form"]/div[1]/div/div[17]/div/div/div/ul/li/div/div[5]/div/div/div/input[2]'

driver.find_element_by_xpath(School_1).click()
elem = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, School_A_1)))
elem.send_keys("Stanford University")
elem.send_keys(Keys.ARROW_DOWN)
auto_option = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, School_A_1)))
auto_option.send_keys(Keys.RETURN)

driver.find_element_by_xpath(Degree_1).click()
elem = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Degree_A_1)))
elem.send_keys("Master")
elem.send_keys(Keys.ARROW_DOWN)
auto_option = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Degree_A_1)))
auto_option.send_keys(Keys.RETURN)

driver.find_element_by_xpath(Discipline_1).click()
elem = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Discipline_A_1)))
elem.send_keys("Software Engineering")
elem.send_keys(Keys.ARROW_DOWN)
auto_option = WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.XPATH, Discipline_A_1)))
auto_option.send_keys(Keys.RETURN)

select = Select(driver.find_element_by_xpath(Start_1))
select.select_by_visible_text('8')

driver.find_element_by_xpath(S_Year_1).send_keys('2016')

select = Select(driver.find_element_by_xpath(End_1))
select.select_by_visible_text('5')

driver.find_element_by_xpath(E_Year_1).send_keys('2019')

driver.find_element_by_xpath(Job_AA).click()

driver.find_element_by_xpath(Company).send_keys('Uber')
driver.find_element_by_xpath(Title).send_keys('Product Manager')
select = Select(driver.find_element_by_xpath(Start_M))
select.select_by_visible_text('11')
driver.find_element_by_xpath(Start_Y).send_keys('2015')

driver.find_element_by_xpath(Current_CHK).click()
